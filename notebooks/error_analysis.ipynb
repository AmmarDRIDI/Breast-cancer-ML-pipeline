# %% [markdown]
# # Error analysis summary
# This notebook documents one confusion-matrix based failure mode from the validation split.

# %%
import json
from pathlib import Path
payload = json.loads(Path('../artifacts/error_analysis.json').read_text())
payload['confusion_matrix'], payload['misclassified_examples'][:1]
# Out:
# Running cells with '.venv (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Ammar Drd/Desktop/React course/React Apps/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
